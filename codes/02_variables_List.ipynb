# %%
first = ['1','2','3','4']

# %%
first, type(first)
# Out:
# (['1', '2', '3', '4'], list)

# %%
first
# Out:
# ['1', '2', '3', '4']

# %%
first[2]
# Out:
# '3'

# %%
first[3]
# Out:
# '4'

# %%
first[0]
# Out:
# '1'

# %%
second = ['morning',
          'afternoon',
          'night']

# %%
second
# Out:
# ['morning', 'afternoon', 'night']

# %%
second[1]
# Out:
# 'afternoon'

# %%
night = 'night'

# %%
third = ['moring',
         'afternoon',
         night]

# %%
third
# Out:
# ['moring', 'afternoon', 'night']

# %% [markdown]
# ### 문제풀이

# %%
# 여기에 fruits 리스트를 만들어 보세요
fruits = ["apple", "banana", "cheery"]

# %%
fruits
# Out:
# ['apple', 'banana', 'cheery']

# %%
colors = ["red", "green", "blue"]

# %%
# 두 번째 값을 출력
colors[1]
# Out:
# 'green'

# %%
pets = ["dog", "parrot", "fish", "red", "green", "blue"]

# %%
# "dog" 값을 출력
# ‘green’ 값을 출력
pets[0] , pets[4]
# Out:
# ('dog', 'green')
