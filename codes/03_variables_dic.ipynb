# %%
first = { "second" : "good" }

# %%
first
# Out:
# {'second': 'good'}

# %%
first["second"]
# Out:
# 'good'

# %%
second = {
    "first" : "good",
    "second" : "bad"
}

# %%
second["second"]
# Out:
# 'bad'

# %%
third = "good_key"

# %%
second = {
    "first" : "good",
    "second" : "bad",
    "not_key" : third
    }

# %%
second["not_key"]
# Out:
# 'good_key'

# %% [markdown]
# ### 문제 풀이

# %%
person = {
    "name" : "Alice",
    "job" : "Enginner"
    }

# %%
person
# Out:
# {'name': 'Alice', 'job': 'Enginner'}

# %%
info = {
    "name" : "Bob",
    "age" : "25",
    "city" : "Seoul"
}

# %%
info["city"]
# Out:
# 'Seoul'

# %%
info
# Out:
# {'name': 'Bob', 'age': '25', 'city': 'Seoul'}

# %%
info["age"] = "30"

# %%
info["name"] = "Charlie"

# %%
info
# Out:
# {'name': 'Charlie', 'age': '30', 'city': 'Seoul'}
