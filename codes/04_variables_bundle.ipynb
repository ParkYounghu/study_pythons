# %%
car_01 = {
    "No" : "1",
    "Brand" : "Toyota",
    "Model" : "Corolla",
    "Color" : "Red"
}

# %%
car_02 = {
    "No" : "2",
    "Brand" : "Honda",
    "Model" : "Civic",
    "Color" : "Black"
}

# %%
car_03 = {
    "no" : "3",
    "Brand" : "BMW",
    "Model" : "X5",
    "Color" : "White"
}

# %%
car_info_list = [car_01, car_02, car_03]

# %%
 car_info_dict = [
    {    "No" : "1",
     "Brand" : "Toyota",
         "Model" : "Corolla",
         "Color" : "Red"
             },
   {
       "No" : "2",
       "Brand" : "Honda",
       "Model" : "Civic",
       "Color" : "Black"
            },
   {
       "No" : "3",
       "Brand" : "BMW",
       "Model" : "X5",
       "Color" : "White"
       }
  ]

# %%
car_info_dict[1]
# Out:
# {'No': '2', 'Brand': 'Honda', 'Model': 'Civic', 'Color': 'Black'}

# %%
# 딕셔너리에서 특정값 확인
# car_info_dict[1]["Model"]
car_info_dict[1]["Brand"]
# Out:
# 'Honda'

# %% [markdown]
# ### 문제풀이

# %%
employees = [
    "Alice", "Bob", "Charlie", "Diana"
]

# %%
employees[0]
# Out:
# 'Alice'

# %%
employees[2]
# Out:
# 'Charlie'

# %%
employee1 = {
    "name" : "Alice",
    "department" : "Sales",
    "position" : "Manager",
    "year" : "2023"
}

# %%
employee1["position"]
# Out:
# 'Manager'

# %%
 all_employees = [
   {    "name" : "Alice",    "department" : "Sales",    "position" : "Manager",    "year" : "2023"    },
   {     "name" : "Bob",    "department" : "IT",    "position" : "Engineer",    "year" : "2022"    },
   {        "name" : "Charlie",    "department" : "HR",    "position" : "staff",    "year" : "2023"    },
    {            "name" : "Diana",    "department" : "Marketing",    "position" : "Analyst",    "year" : "2024"    }
 ]

# %%
all_employees[2]
# Out:
# {'name': 'Charlie', 'department': 'HR', 'position': 'staff', 'year': '2023'}

# %%
all_employees[1]["position"]
# Out:
# 'Engineer'
