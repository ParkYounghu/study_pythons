# %% [markdown]
# ## 문제 풀이
# - 두 문자열 변수를 선언해서 각각 변수에 값을 넣고, + 기호를 이용해 이어 붙이는 코드를 작성해 보세요.
# - 변수 이름 : first, second, result

# %%
first = "Lunch is"

# %%
second = "delicious."

# %%
result = first + " " + second

# %%
result
# Out:
# 'Lunch is delicious.'
